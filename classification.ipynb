# %%
import numpy as np


x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,1])

x
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
y
# Out:
# array([0, 1, 1, 1])

# %%
w = np.array([1,1])
b= -0.5

# %%
pred = []

for a in x:
    y_hat = np.dot(a,w)+b
    pred.append(activation(y_hat))

# %%
pred
# Out:
# [np.float64(-0.5), np.float64(0.5), np.float64(0.5), np.float64(1.5)]

# %%
def activation(z):
    if z > 0:
        return 1
    else:
        return 0

# %%
#Linear Regressio

# %%
import matplotlib.pyplot as plt
from sklearn import datasets,linear_model


x,y = datasets.load_diabetes(return_X_y=True)

x.shape
# y.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
plt.scatter(x[:,2],y)

# %%
reg = linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
plt.scatter(x_test[:,2],y_test)

# %%
model = reg.fit(x_train,y_train)

# %%
predict = model.predict(x_test)

# %%
predict
# Out:
# array([105.74286698, 228.75133495, 124.44952402,  50.24216978,
#        152.53994074, 255.92251974, 141.8588675 , 260.87308848,
#        174.25036097,  66.16781344,  59.62113794, 160.42944746,
#        192.74920592, 204.98722839,  77.80474415, 291.50133799,
#        260.0184051 ,  39.1521198 ,  58.52791332, 191.21925746,
#        228.97950306, 103.14284608, 102.18934064, 213.98515737,
#        126.60462579, 114.38732852,  76.82356151, 199.76627689,
#         93.04074403,  74.76874447, 133.80539131, 160.62816902,
#        114.47941832, 178.99764352, 199.0019466 , 198.12945208,
#         80.78613366, 141.12970789, 198.78753526, 152.88313767,
#        146.21560075, 179.64257417,  72.50697717, 160.50181823,
#        157.88502684])

# %%
plt.scatter(predict,y_test)

# %%
acc = reg.score(x,y)
acc
# Out:
# 0.5162590769645173

# %%
# Code source: Jaques Grobler
# License: BSD 3 clause

import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
acc =  regr.score(diabetes_X,diabetes_y)
acc
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 acc =  regr.score(diabetes_X[:,2],diabetes_y)
#       2 acc
#
# IndexError: index 2 is out of bounds for axis 1 with size 1
